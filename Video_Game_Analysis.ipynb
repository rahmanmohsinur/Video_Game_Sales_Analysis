# %%
# Uncomment the next line & run the cell to install necessary modules for this notebook.
#!pip install pandas==2.2.2 numpy==2.0.2 matplotlib==3.10.0 seaborn==0.13.2 scipy==1.16.2 statsmodels==0.14.5 scikit-learn==1.6.1 plotly==5.24.1 ipython==7.34.0

# %%
# Imports & settings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

import plotly.express as px
import plotly.colors as pc

from scipy import stats
from scipy.stats import gaussian_kde
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
#from statsmodels.tsa.seasonal import seasonal_decompose
from IPython.display import display, Markdown

# %% [markdown]
# # Data Loading and Inspection

# %%
# Change file path or dataset name if necessary
file_path = '/content/VGSales_4054.csv'

# Load the dataset with Pandas
df = pd.read_csv(file_path, low_memory=False)

# Display the first few rows to observe data structure
print("The first few rows of the data set:\n")
display(df.head())
# Out:
# The first few rows of the data set:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08       NaN      6.81         0.77         40.24
# 2     15.85     12.88      3.79          NaN         35.82
# 3     15.75     11.01      3.28         2.96           NaN
# 4     11.27      8.89     10.22         1.00         31.37

# %%
print("View the type of data:")
print (df.info())
# Out:
# View the type of data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          5000 non-null   int64
#  1   Name          5000 non-null   object
#  2   Platform      5000 non-null   object
#  3   Year          4931 non-null   float64
#  4   Genre         5000 non-null   object
#  5   Publisher     4990 non-null   object
#  6   NA_Sales      5000 non-null   float64
#  7   EU_Sales      4999 non-null   float64
#  8   JP_Sales      5000 non-null   float64
#  9   Other_Sales   4999 non-null   float64
#  10  Global_Sales  4999 non-null   float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 429.8+ KB
# None

# %%
# Checking duplicate rows
print("Duplicate rows:", df.duplicated().sum())

# Checking for missing values inside of the dataset
print ( '\nMissing values')
print (df. isnull().sum())
# Out:
# Duplicate rows: 0
#
# Missing values
# Rank             0
# Name             0
# Platform         0
# Year            69
# Genre            0
# Publisher       10
# NA_Sales         0
# EU_Sales         1
# JP_Sales         0
# Other_Sales      1
# Global_Sales     1
# dtype: int64

# %% [markdown]
# # Data Pre-Processing & Feature Engineering

# %%
# Trim whitespace in object columns
str_cols = df.select_dtypes(include='object').columns.tolist()
for c in str_cols:
    df[c] = df[c].astype(str).str.strip()

# Standardize column names
df.columns = [c.strip().replace(' ', '_') for c in df.columns]

# Replace NaN values in Publisher with 'Unknown Publisher'
df['Publisher'] = df['Publisher'].fillna('Unknown Publisher')

# Year handling: create a single column 'Release_Year' with date format (year only)
if 'Year' in df.columns:
    # Convert to numeric, invalid parsing becomes NaN
    df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
    # Create Release_Year as datetime, using January 1st for missing day/month
    df['Release_Year'] = pd.to_datetime(df['Year'], format='%Y', errors='coerce')

# Rank conversions
if 'Rank' in df.columns:
    # sometimes strings exist
    df['Rank'] = pd.to_numeric(df['Rank'], errors='coerce')

# Identify regional sales columns (exclude 'Global_Sales')
region_cols = [c for c in df.columns if c.endswith('_Sales') and c != 'Global_Sales']
print('Detected regional columns:', region_cols)

# Fill NaN values in regional sales columns with the average of that column
for col in region_cols:
    mean_value = df[col].mean()
    df[col] = df[col].fillna(mean_value)

# Compute Global_Sales if missing
df['Global_Sales'] = df['Global_Sales'].fillna(df[region_cols].sum(axis=1))

# Check remaining missing values
missing = df.isna().sum().sort_values(ascending=False)
print('Remaining missing values:')
display(missing[missing > 0].head())
# Out:
# Detected regional columns: ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
# Remaining missing values:
# Year            69
# Release_Year    69
# dtype: int64

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales   EU_Sales  JP_Sales  Other_Sales  Global_Sales Release_Year
# 0     41.49  29.020000      3.77     8.460000         82.74   2006-01-01
# 1     29.08   0.425815      6.81     0.770000         40.24   1985-01-01
# 2     15.85  12.880000      3.79     0.138948         35.82   2008-01-01
# 3     15.75  11.010000      3.28     2.960000         33.00   2009-01-01
# 4     11.27   8.890000     10.22     1.000000         31.37   1996-01-01

# %%
# Dropped the original 'Year' column since no longer needed
#df.drop(columns=['Year'], inplace=True)

# Calculating the total number of missing cells in the dataset
null_values = df.isnull().sum().sum()
print("\nTotal number of null values in the data set are:", null_values)

# Calculate total fields in the data set
total_values = df.size
print('Total data fields in the report are:', total_values)

# Calculate the percentage of missing valuesu of data set
anomalies = (null_values / total_values) * 100
print (f'The missing values represent {anomalies:.2f}% of the entire data values.')
# Out:
# Total number of null values in the data set are: 138
# Total data fields in the report are: 60000
# The missing values represent 0.23% of the entire data values.

# %%
# Remove rows with empty vallues
df.dropna(axis=0,inplace=True)

# Check for missing values after imputation
print("Number of null values:", df.isnull().sum().sum())

# Duplicates after removal
print("Number of duplicate rows:", df.duplicated().sum(), "\n")

print (df.info())
# Out:
# Number of null values: 0
# Number of duplicate rows: 0
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 4931 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          4931 non-null   int64
#  1   Name          4931 non-null   object
#  2   Platform      4931 non-null   object
#  3   Year          4931 non-null   float64
#  4   Genre         4931 non-null   object
#  5   Publisher     4931 non-null   object
#  6   NA_Sales      4931 non-null   float64
#  7   EU_Sales      4931 non-null   float64
#  8   JP_Sales      4931 non-null   float64
#  9   Other_Sales   4931 non-null   float64
#  10  Global_Sales  4931 non-null   float64
#  11  Release_Year  4931 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(1), object(4)
# memory usage: 500.8+ KB
# None

# %% [markdown]
# # Descriptive Statistical Analysis

# %%
# Count unique values across multiple non-numeric columns
total_publishers = df['Publisher'].nunique()
total_platforms = df['Platform'].nunique()
total_genres = df['Genre'].nunique()
total_names = df['Name'].nunique()

print("Total Unique Publishers:", total_publishers)
print("Total Unique Platforms:", total_platforms)
print("Total Unique Genres:", total_genres)
print("Total Unique Names:", total_names)

# Declaration of a variable to hold numerical sales data
numerical_data = df.loc[:, df.dtypes == 'float64']
print("\n\nInitial Data Summary:\n")
display( numerical_data.describe().round(4))
# Out:
# Total Unique Publishers: 194
# Total Unique Platforms: 26
# Total Unique Genres: 12
# Total Unique Names: 3507
#
#
# Initial Data Summary:
#             Year   NA_Sales   EU_Sales   JP_Sales  Other_Sales  Global_Sales
# count  4931.0000  4931.0000  4931.0000  4931.0000    4931.0000     4931.0000
# mean   2005.3529     0.7387     0.4278     0.1960       0.1395        1.5022
# std       6.6335     1.3793     0.8593     0.5511       0.3237        2.6019
# min    1980.0000     0.0000     0.0000     0.0000       0.0000        0.3800
# 25%    2002.0000     0.2400     0.0900     0.0000       0.0300        0.5400
# 50%    2007.0000     0.4200     0.2200     0.0000       0.0700        0.8300
# 75%    2010.0000     0.7800     0.4500     0.1300       0.1400        1.5100
# max    2016.0000    41.4900    29.0200    10.2200      10.5700       82.7400

# %%
def kpis(df, date_col='Release_Year'):
    total_sales = df['Global_Sales'].sum()
    if date_col in df.columns and not df[date_col].isna().all():
        df_year = df.copy()
        df_year['year'] = df_year[date_col].dt.year
        yearly = df_year.groupby('year')['Global_Sales'].sum().sort_index()
        if len(yearly) >= 2:
            yoy = (yearly.iloc[-1] - yearly.iloc[-2]) / yearly.iloc[-2] if yearly.iloc[-2] != 0 else np.nan
        else:
            yoy = np.nan
        first_year, last_year = yearly.index.min(), yearly.index.max()
    else:
        yoy = np.nan
        first_year, last_year = None, None

    top_platform = df.groupby('Platform', as_index=False)['Global_Sales'].sum() if 'Platform' in df.columns else pd.DataFrame()
    top_platform = top_platform.sort_values('Global_Sales', ascending=False).head(1)['Platform'].iloc[0] if not top_platform.empty else None
    top_genre = df.groupby('Genre', as_index=False)['Global_Sales'].sum() if 'Genre' in df.columns else pd.DataFrame()
    top_genre = top_genre.sort_values('Global_Sales', ascending=False).head(1)['Genre'].iloc[0] if not top_genre.empty else None
    avg_per_title = df['Global_Sales'].mean()
    return dict(
        total_sales=total_sales,
        yoy=yoy,
        first_year=first_year,
        last_year=last_year,
        top_platform=top_platform,
        top_genre=top_genre,
        avg_per_title=avg_per_title
    )


# KPIs
kpis = kpis(df)
display(Markdown("## Executive KPIs"))
display(Markdown(f"- **Total global sales:** {kpis['total_sales']:.2f}"))
if kpis['first_year'] is not None:
    display(Markdown(f"- **Period:** {kpis['first_year']} — {kpis['last_year']}"))
display(Markdown(f"- **YoY (latest year):** {kpis['yoy']:.2%}" if not np.isnan(kpis['yoy']) else "- **YoY:** N/A"))
display(Markdown(f"- **Top platform:** {kpis['top_platform']}"))
display(Markdown(f"- **Top genre:** {kpis['top_genre']}"))
display(Markdown(f"- **Avg sales per title:** {kpis['avg_per_title']:.3f}"))
# Out:
# ## Executive KPIs
# - **Total global sales:** 7407.47
# - **Period:** 1980 — 2016
# - **YoY (latest year):** -79.64%
# - **Top platform:** PS2
# - **Top genre:** Action
# - **Avg sales per title:** 1.502

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Use seaborn style
sns.set(style="whitegrid")

# Select regional sales
region_cols = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
sales_totals = df[region_cols].sum()

# Pie chart
plt.figure(figsize=(6, 6))
plt.pie(
    sales_totals,
    labels=sales_totals.index,
    autopct='%1.1f%%',        # show percentages with 1 decimal
    startangle=140,
    colors=sns.color_palette("Set2")  # Seaborn color palette
)
plt.title("Regional Sales Distribution", fontsize=14)
plt.show()

# %%
# Function Definition for top ten bar chart
def top_cat_sale(df, by='Genre', n=10, sales_col='Global_Sales', title=None,
                 width=1000, height=500, palette=None):
    """
    Creates a horizontal annotated bar chart showing the top categories by total sales.
    """
    if by not in df.columns:
        display(Markdown(f"Column `{by}` not in data."))
        return

    # Aggregate and sort data
    agg = (
        df.groupby(by, as_index=False)[sales_col]
        .sum()
        .sort_values(sales_col, ascending=False)
        .head(n)
    )

    # Create horizontal bar chart
    fig = px.bar(
        agg,
        x=sales_col,
        y=by,
        orientation='h',
        text=sales_col,
        title=title or f"Top {n} {by}s by {sales_col}",
        width=width,
        height=height,
        color=by,
        color_discrete_sequence=palette
    )

    # Update layout and annotation
    fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
    fig.update_layout(yaxis={'categoryorder': 'total ascending'})
    fig.show()


# Top 10 Genres by Global Sales (Pastel colors)
top_cat_sale(
    df,
    by='Genre',
    n=10,
    title="Top 10 Genres by Global Sales",
    width=1000,
    height=500,
    palette=px.colors.qualitative.Pastel
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4a2f2b89-6d29-448c-8bfc-9c7127a2f00a" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a2f2b89-6d29-448c-8bfc-9c7127a2f00a")) {                    Plotly.newPlot(                        "4a2f2b89-6d29-448c-8bfc-9c7127a2f00a",                        [{"alignmentgroup":"True","hovertemplate":"Genre=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Action","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"Action","offsetgroup":"Action","orientation":"h","showlegend":true,"text":[1432.93],"textposition":"outside","x":[1432.93],"xaxis":"x","y":["Action"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Genre=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sports","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Sports","offsetgroup":"Sports","orientation":"h","showlegend":true,"text":[1093.15],"textposition":"outside","x":[1093.15],"xaxis":"x","y":["Sports"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Genre=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shooter","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"Shooter","offsetgroup":"Shooter","orientation":"h","showlegend":true,"text":[930.73],"textposition":"outside","x":[930.73],"xaxis":"x","y":["Shooter"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Genre=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Role-Playing","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"Role-Playing","offsetgroup":"Role-Playing","orientation":"h","showlegend":true,"text":[795.55],"textposition":"outside","x":[795.55],"xaxis":"x","y":["Role-Playing"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Genre=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Platform","marker":{"color":"rgb(135, 197, 95)","pattern":{"shape":""}},"name":"Platform","offsetgroup":"Platform","orientation":"h","showlegend":true,"text":[759.0600000000001],"textposition":"outside","x":[759.0600000000001],"xaxis":"x","y":["Platform"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Genre=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Misc","marker":{"color":"rgb(158, 185, 243)","pattern":{"shape":""}},"name":"Misc","offsetgroup":"Misc","orientation":"h","showlegend":true,"text":[640.61],"textposition":"outside","x":[640.61],"xaxis":"x","y":["Misc"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Genre=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Racing","marker":{"color":"rgb(254, 136, 177)","pattern":{"shape":""}},"name":"Racing","offsetgroup":"Racing","orientation":"h","showlegend":true,"text":[621.23],"textposition":"outside","x":[621.23],"xaxis":"x","y":["Racing"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Genre=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fighting","marker":{"color":"rgb(201, 219, 116)","pattern":{"shape":""}},"name":"Fighting","offsetgroup":"Fighting","orientation":"h","showlegend":true,"text":[366.41],"textposition":"outside","x":[366.41],"xaxis":"x","y":["Fighting"],"yaxis":"y","type":"bar","te ...

# %%
# Top 10 Platforms by Global Sales (Viridis sequential gradient)
top_cat_sale(
    df,
    by='Platform',
    n=10,
    title="Top 10 Platforms by Global Sales",
    width=1000,
    height=500,
    palette=px.colors.sequential.Viridis
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b0f1f211-33c9-4b69-90a1-dffe77d5c655" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0f1f211-33c9-4b69-90a1-dffe77d5c655")) {                    Plotly.newPlot(                        "b0f1f211-33c9-4b69-90a1-dffe77d5c655",                        [{"alignmentgroup":"True","hovertemplate":"Platform=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PS2","marker":{"color":"#440154","pattern":{"shape":""}},"name":"PS2","offsetgroup":"PS2","orientation":"h","showlegend":true,"text":[1047.61],"textposition":"outside","x":[1047.61],"xaxis":"x","y":["PS2"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Platform=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"X360","marker":{"color":"#482878","pattern":{"shape":""}},"name":"X360","offsetgroup":"X360","orientation":"h","showlegend":true,"text":[861.85],"textposition":"outside","x":[861.85],"xaxis":"x","y":["X360"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Platform=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PS3","marker":{"color":"#3e4989","pattern":{"shape":""}},"name":"PS3","offsetgroup":"PS3","orientation":"h","showlegend":true,"text":[844.09],"textposition":"outside","x":[844.09],"xaxis":"x","y":["PS3"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Platform=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wii","marker":{"color":"#31688e","pattern":{"shape":""}},"name":"Wii","offsetgroup":"Wii","orientation":"h","showlegend":true,"text":[787.8199999999999],"textposition":"outside","x":[787.8199999999999],"xaxis":"x","y":["Wii"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Platform=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DS","marker":{"color":"#26828e","pattern":{"shape":""}},"name":"DS","offsetgroup":"DS","orientation":"h","showlegend":true,"text":[628.01],"textposition":"outside","x":[628.01],"xaxis":"x","y":["DS"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Platform=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PS","marker":{"color":"#1f9e89","pattern":{"shape":""}},"name":"PS","offsetgroup":"PS","orientation":"h","showlegend":true,"text":[618.94],"textposition":"outside","x":[618.94],"xaxis":"x","y":["PS"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Platform=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PS4","marker":{"color":"#35b779","pattern":{"shape":""}},"name":"PS4","offsetgroup":"PS4","orientation":"h","showlegend":true,"text":[251.71],"textposition":"outside","x":[251.71],"xaxis":"x","y":["PS4"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Platform=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NES","marker":{"color":"#6ece58","pattern":{"shape":""}},"name":"NES","offsetgroup":"NES","orientation":"h","showlegend":true,"text":[249.57],"textposition":"outside","x":[249.57],"xaxis":"x","y":["NES"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Platform=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GB","marker":{"color":"#b5de ...

# %%
# Top 10 Publishers by Global Sales (Set2 qualitative palette)
top_cat_sale(
    df,
    by='Publisher',
    n=10,
    title="Top 10 Publishers by Global Sales",
    width=1000,
    height=500,
    palette=px.colors.qualitative.Set2
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c983e638-e3b5-40bf-b736-be52bdd1e7d6" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c983e638-e3b5-40bf-b736-be52bdd1e7d6")) {                    Plotly.newPlot(                        "c983e638-e3b5-40bf-b736-be52bdd1e7d6",                        [{"alignmentgroup":"True","hovertemplate":"Publisher=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nintendo","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"Nintendo","offsetgroup":"Nintendo","orientation":"h","showlegend":true,"text":[1748.39],"textposition":"outside","x":[1748.39],"xaxis":"x","y":["Nintendo"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Publisher=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electronic Arts","marker":{"color":"rgb(252,141,98)","pattern":{"shape":""}},"name":"Electronic Arts","offsetgroup":"Electronic Arts","orientation":"h","showlegend":true,"text":[993.51],"textposition":"outside","x":[993.51],"xaxis":"x","y":["Electronic Arts"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Publisher=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Activision","marker":{"color":"rgb(141,160,203)","pattern":{"shape":""}},"name":"Activision","offsetgroup":"Activision","orientation":"h","showlegend":true,"text":[629.34],"textposition":"outside","x":[629.34],"xaxis":"x","y":["Activision"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Publisher=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sony Computer Entertainment","marker":{"color":"rgb(231,138,195)","pattern":{"shape":""}},"name":"Sony Computer Entertainment","offsetgroup":"Sony Computer Entertainment","orientation":"h","showlegend":true,"text":[548.6],"textposition":"outside","x":[548.6],"xaxis":"x","y":["Sony Computer Entertainment"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Publisher=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ubisoft","marker":{"color":"rgb(166,216,84)","pattern":{"shape":""}},"name":"Ubisoft","offsetgroup":"Ubisoft","orientation":"h","showlegend":true,"text":[385.45],"textposition":"outside","x":[385.45],"xaxis":"x","y":["Ubisoft"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Publisher=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Take-Two Interactive","marker":{"color":"rgb(255,217,47)","pattern":{"shape":""}},"name":"Take-Two Interactive","offsetgroup":"Take-Two Interactive","orientation":"h","showlegend":true,"text":[365.06],"textposition":"outside","x":[365.06],"xaxis":"x","y":["Take-Two Interactive"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Publisher=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"THQ","marker":{"color":"rgb(229,196,148)","pattern":{"shape":""}},"name":"THQ","offsetgroup":"THQ","orientation":"h","showlegend":true,"text":[268.19],"textposition":"outside","x":[268.19],"xaxis":"x","y":["THQ"],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"Publisher=%{y}\u003cbr\u003eGlobal_Sales=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Microsoft Game Studios","marker":{"color":"rgb(179,179,179)","pattern":{"shape":""}},"name":"Microsoft Game S ...

# %%
# Cell: Sales over time (aggregate) with annotations for peaks
def aggregate_timeseries(df, date_col='Release_Year', sales_col='Global_Sales', freq='YE'):
    ts = df.dropna(subset=[date_col]).copy()
    ts = ts.set_index(date_col).resample(freq)[sales_col].sum().rename(sales_col).to_frame().reset_index()
    return ts

if not df['Release_Year'].isna().all():
    ts = aggregate_timeseries(df, freq='YE')
    fig = px.line(ts, x='Release_Year', y='Global_Sales', title='Global Sales Over Time (Yearly)')
    # annotate top peaks
    peaks = ts.sort_values('Global_Sales', ascending=False).head(3)
    for _, r in peaks.iterrows():
        fig.add_annotation(x=r['Release_Year'], y=r['Global_Sales'],
                           text=f"{r['Global_Sales']:.2f}", showarrow=True, arrowhead=2)
    fig.update_layout(width=1000, height=500)
    fig.show()
else:
    display(Markdown("No valid release_date found — cannot produce time series."))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1dd26963-c790-4738-8bbb-7a95fbee266a" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dd26963-c790-4738-8bbb-7a95fbee266a")) {                    Plotly.newPlot(                        "1dd26963-c790-4738-8bbb-7a95fbee266a",                        [{"hovertemplate":"Release_Year=%{x}\u003cbr\u003eGlobal_Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1980-12-31T00:00:00","1981-12-31T00:00:00","1982-12-31T00:00:00","1983-12-31T00:00:00","1984-12-31T00:00:00","1985-12-31T00:00:00","1986-12-31T00:00:00","1987-12-31T00:00:00","1988-12-31T00:00:00","1989-12-31T00:00:00","1990-12-31T00:00:00","1991-12-31T00:00:00","1992-12-31T00:00:00","1993-12-31T00:00:00","1994-12-31T00:00:00","1995-12-31T00:00:00","1996-12-31T00:00:00","1997-12-31T00:00:00","1998-12-31T00:00:00","1999-12-31T00:00:00","2000-12-31T00:00:00","2001-12-31T00:00:00","2002-12-31T00:00:00","2003-12-31T00:00:00","2004-12-31T00:00:00","2005-12-31T00:00:00","2006-12-31T00:00:00","2007-12-31T00:00:00","2008-12-31T00:00:00","2009-12-31T00:00:00","2010-12-31T00:00:00","2011-12-31T00:00:00","2012-12-31T00:00:00","2013-12-31T00:00:00","2014-12-31T00:00:00","2015-12-31T00:00:00","2016-12-31T00:00:00"],"xaxis":"x","y":[10.53,31.330000000000002,25.69,15.66,50.089999999999996,53.89,36.41,21.33,46.95,73.24000000000001,48.76,27.73,73.82,41.29,66.69,65.94,173.48,171.76,223.77,220.45,165.85,287.58,316.66,285.22,353.79,370.42,439.06,514.65,559.87,537.92,488.89,409.33,313.28,325.58,291.86,223.24,45.46],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[ ...

# %%
# Raw Global Sales
plt.figure(figsize=(16, 4))
sns.histplot(df['Global_Sales'], bins=60, color='green', stat='density')  # histogram
sns.kdeplot(df['Global_Sales'], color='darkred', linewidth=2)  # KDE line
plt.title('Distribution of Global Sales (raw)')
plt.xlabel('Global Sales')
plt.ylabel('Density')
plt.show()

# %%
# Log-transformed Global Sales
df['Log_Global_Sales'] = np.log1p(df['Global_Sales'])

plt.figure(figsize=(16, 4))
sns.histplot(df['Log_Global_Sales'], bins=60, color='green', stat='density')
sns.kdeplot(df['Log_Global_Sales'], color='darkred', linewidth=2)
plt.title('Distribution of log(1 + Global_Sales)')
plt.xlabel('log(1 + Global Sales)')
plt.ylabel('Density')
plt.show()

# %%
# Boxplot of Global Sales by Genre
if 'Genre' in df.columns and 'Global_Sales' in df.columns:
    plt.figure(figsize=(12,6))
    sns.boxplot(x='Genre', y='Global_Sales', data=df)
    plt.xticks(rotation=90)
    plt.yscale('symlog')
    plt.title('Global Sales by Genre (symlog scale)')
    plt.show()

# %%
# Numerical columns
numeric_columns = df.select_dtypes(include=['int64', 'float64'])

# Calculation of z-scores
z_scores = np.abs((numeric_columns - numeric_columns.mean()) / numeric_columns.std())

# Set threshold as 3 standard deviations
threshold = 3

# Counting outliers in each column
outliers = (z_scores > threshold).sum()

# Print outliers for each column
print("Number of outliers:")
print(outliers)
# Out:
# Number of outliers:
# Rank                 0
# Year                97
# NA_Sales            62
# EU_Sales            68
# JP_Sales            94
# Other_Sales         61
# Global_Sales        71
# Log_Global_Sales    93
# dtype: int64

# %% [markdown]
# # Statistical Inferential Analysis with Hypothesis Testing

# %%
# Inferential statistics
# ANOVA: Identify if there are enough diffrence amoung genres in mean global sales.
if 'Genre' in df.columns and 'Global_Sales' in df.columns:
    genre_counts = df['Genre'].value_counts()
    kept_genres = genre_counts[genre_counts >= 30].index.tolist()
    if len(kept_genres) > 1:
        test_df = df[df['Genre'].isin(kept_genres)].copy()
        groups = [group['Global_Sales'].dropna().values for name, group in test_df.groupby('Genre')]
        fstat, pval = stats.f_oneway(*groups)
        print('ANOVA across genres: F-stat =', fstat, ', p-value =', pval)
    else:
        print('Not enough genres with >=30 records for robust ANOVA.')

# Pairwise t-test: Identifying the difference between top two genres in mean global sales.
if 'Genre' in df.columns:
    top_two = df['Genre'].value_counts().index[:2].tolist()
    if len(top_two) == 2:
        a = df[df['Genre']==top_two[0]]['Global_Sales'].dropna()
        b = df[df['Genre']==top_two[1]]['Global_Sales'].dropna()
        tstat, pval = stats.ttest_ind(a, b, equal_var=False)
        print(f'T-test {top_two[0]} vs {top_two[1]}: t={tstat:.3f}, p={pval:.3g}')
# Out:
# ANOVA across genres: F-stat = 4.086933002426457 , p-value = 5.276246091612939e-06
# T-test Action vs Sports: t=0.126, p=0.9

# %% [markdown]
# # Correlation & Trend Analysis

# %%
# Correlation heatmap for numeric columns
selected_columns = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']

# Select numerical columns for correlation analysis
selected_columns = ['Release_Year', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
numerical_columns = df[selected_columns]

# Produce correlation matrix with pandas
correlation_matrix = numerical_columns.corr()

# Print correlation matrix with column names aligned
print("Correlation Matrix:")
print(correlation_matrix.to_string())
# Out:
# Correlation Matrix:
#               Release_Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Release_Year      1.000000 -0.068298  0.085581 -0.201292     0.126351     -0.035596
# NA_Sales         -0.068298  1.000000  0.720266  0.422963     0.570725      0.932261
# EU_Sales          0.085581  0.720266  1.000000  0.397293     0.669402      0.879184
# JP_Sales         -0.201292  0.422963  0.397293  1.000000     0.237458      0.596586
# Other_Sales       0.126351  0.570725  0.669402  0.237458     1.000000      0.695579
# Global_Sales     -0.035596  0.932261  0.879184  0.596586     0.695579      1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df[selected_columns].corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title('Numeric correlation matrix')
plt.show()

# %%
# Yearly Global Sales Polynomial Trend
# Group the data by year and calculate total Global Sales
yearly_sales = df.groupby('Release_Year')['Global_Sales'].sum().reset_index()

# Ensure Release_Year is in datetime format for plotting
yearly_sales['Date'] = pd.to_datetime(yearly_sales['Release_Year'].astype(str) + '-01-01')

# Fit a polynomial trend line (degree 3)
coefficients = np.polyfit(np.arange(len(yearly_sales)), yearly_sales['Global_Sales'], 3)
poly_function = np.poly1d(coefficients)

# Plot the scatter plot with trend line
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Date', y='Global_Sales', data=yearly_sales, color='skyblue')
plt.plot(yearly_sales['Date'], poly_function(np.arange(len(yearly_sales))),
         color='red', linestyle='--', label='Polynomial Trend Line')
plt.title('Yearly Global Sales with Polynomial Trend Line')
plt.xlabel('Year')
plt.ylabel('Global Sales')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-1599955928.py:6: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %% [markdown]
# # Forecasting Future Video Game Sales

# %%
# Time Series Analysis: Global Sales
if 'Release_Year' in df.columns and df['Release_Year'].notna().any():
    # Aggregate yearly sales
    ts = df.groupby('Release_Year')['Global_Sales'].sum().sort_index()

    # check min/max of Release_Year
    print("Min Release Year:", df['Release_Year'].min())
    print("Max Release Year:", df['Release_Year'].max())

    # Handle datetime vs numeric year
    if np.issubdtype(ts.index.dtype, np.datetime64):
        ts.index = pd.to_datetime(ts.index).to_period("Y").to_timestamp()
    else:
        ts.index = pd.to_numeric(ts.index, errors='coerce')
        ts = ts.dropna()
        ts = ts[(ts.index >= 1970) & (ts.index <= 2030)]
        ts.index = pd.to_datetime(ts.index.astype(int).astype(str), format='%Y')

    # Ensure yearly frequency
    ts = ts.asfreq('YS')

    # Check if empty
    if ts.empty:
        print("Time series is empty after processing.")
    else:
        # display(ts)
        extremes = ts.loc[[ts.idxmin(), ts.idxmax()]]
        display(extremes)

else:
    print('Release_Year or Global_Sales missing — cannot build time series aggregation.')
# Out:
# Min Release Year: 1980-01-01 00:00:00
# Max Release Year: 2016-01-01 00:00:00
# Release_Year
# 1980-01-01     10.53
# 2008-01-01    559.87
# Name: Global_Sales, dtype: float64

# %%
# Forcasting Global Sales
try:
    # Upsample yearly data to monthly
    ts_monthly = ts.resample('MS').interpolate(method='linear')

    forcast = ARIMA(ts_monthly.dropna(), order=(1,1,1))
    forcast_res = forcast.fit()

    # Forecast 12 months
    n_forecast = 12
    fc = forcast_res.get_forecast(steps=n_forecast)
    fc_index = pd.date_range(ts_monthly.index[-1] + pd.DateOffset(months=1),
                             periods=n_forecast, freq='MS')

    # Put forecast in DataFrame
    forecast_df = pd.DataFrame({
        'Forecast': fc.predicted_mean,
        'Lower CI': fc.conf_int().iloc[:,0],
        'Upper CI': fc.conf_int().iloc[:,1]
    }, index=fc_index)

    print("\n12-Month Forecast:")
    print(forecast_df)
except Exception as e:
    print("Error:", e)
# Out:
# 12-Month Forecast:
#              Forecast    Lower CI   Upper CI
# 2016-02-01  31.342537   28.341173  34.343901
# 2016-03-01  17.907861   11.253310  24.562413
# 2016-04-01   5.122951   -5.858151  16.104052
# 2016-05-01  -7.043621  -22.869101   8.781859
# 2016-06-01 -18.621759  -39.703108   2.459589
# 2016-07-01 -29.639924  -56.310545  -2.969303
# 2016-08-01 -40.125198  -72.658218  -7.592177
# 2016-09-01 -50.103354  -88.723767 -11.482941
# 2016-10-01 -59.598919 -104.492336 -14.705501
# 2016-11-01 -68.635233 -119.954476 -17.315991
# 2016-12-01 -77.234508 -135.104724 -19.364292
# 2017-01-01 -85.417882 -149.940626 -20.895138

# %%
try:
    # Plot forecast
    plt.figure(figsize=(10,5))
    plt.plot(ts_monthly, label='Observed')
    plt.plot(forecast_df.index, forecast_df['Forecast'], marker='.', color='red', label='Forecast')
    plt.fill_between(forecast_df.index,
                     forecast_df['Lower CI'],
                     forecast_df['Upper CI'],
                     color='pink', alpha=0.75, label='95% CI')
    plt.title('Forecast of Global Sales (Monthly)')
    plt.ylabel('Global_Sales')
    plt.legend()
    plt.show()
except Exception as e:
    print("Error:", e)

# %%
# ==============================================================
# INTERACTIVE VIDEO GAME SALES DASHBOARD (10x10 Figure + Subplots)
# With Year Range Slider (ipywidgets + Matplotlib + Seaborn)
# ==============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import widgets, interactive_output, VBox, HBox, HTML
from IPython.display import display, Markdown, clear_output

# ==============================================================
# DATA PREPARATION
# ==============================================================
# Load dataset (replace with your file path if needed)
#df = pd.read_csv('VGSales_4054.csv')

# Basic cleaning
#df.columns = [c.strip().replace(" ", "_") for c in df.columns]
#df["Publisher"] = df["Publisher"].fillna("Unknown Publisher")
#df["Year"] = pd.to_numeric(df["Year"], errors="coerce")
#df["Year"] = df["Year"].fillna(df["Year"].median()).astype(int)
#df["Global_Sales"] = df["Global_Sales"].fillna(
#    df[["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]].sum(axis=1)
#)
#df.dropna(subset=["Genre", "Platform", "Publisher"], inplace=True)
sns.set(style="whitegrid")

# Determine year range
min_year, max_year = int(df["Year"].min()), int(df["Year"].max())

# ==============================================================
# WIDGETS
# ==============================================================
year_range_slider = widgets.IntRangeSlider(
    value=[min_year, max_year],
    min=min_year,
    max=max_year,
    step=1,
    description="Years:",
    continuous_update=False,
    layout=widgets.Layout(width='95%')
)

platform_dd = widgets.Dropdown(
    options=["All"] + sorted(df["Platform"].unique().tolist()),
    value="All",
    description="Platform:",
)

genre_dd = widgets.Dropdown(
    options=["All"] + sorted(df["Genre"].unique().tolist()),
    value="All",
    description="Genre:",
)

publisher_dd = widgets.Dropdown(
    options=["All"] + sorted(df["Publisher"].unique().tolist()),
    value="All",
    description="Publisher:",
)

region_dd = widgets.Dropdown(
    options=["Global_Sales", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"],
    value="Global_Sales",
    description="Region:",
)

# ==============================================================
# KPI DISPLAY FUNCTION
# ==============================================================
def display_kpis(df_filtered):
    total_sales = df_filtered["Global_Sales"].sum()
    top_game = df_filtered.loc[df_filtered["Global_Sales"].idxmax(), "Name"]
    top_genre = df_filtered.groupby("Genre")["Global_Sales"].sum().idxmax()
    avg_sales = df_filtered["Global_Sales"].mean()

    kpi_html = f"""
    <div style="display:flex; justify-content:space-around; background:#F9F9F9;
                border-radius:0px; padding:15px 0; margin-bottom:20px;">
        <div><b>Total Sales: </b>{total_sales:.2f}M</div>
        <div><b>Top Game: </b>{top_game}</div>
        <div><b>Top Genre: </b>{top_genre}</div>
        <div><b>Avg Sales/Game: </b>{avg_sales:.2f}M</div>
    </div>
    """
    display(HTML(kpi_html))

# ==============================================================
# MAIN DASHBOARD UPDATE FUNCTION
# ==============================================================
def update_dashboard(years, platform, genre, publisher, region):
    clear_output(wait=True)
    year_min, year_max = years

    # Filter data
    df_filtered = df[(df["Year"] >= year_min) & (df["Year"] <= year_max)]
    if platform != "All":
        df_filtered = df_filtered[df_filtered["Platform"] == platform]
    if genre != "All":
        df_filtered = df_filtered[df_filtered["Genre"] == genre]
    if publisher != "All":
        df_filtered = df_filtered[df_filtered["Publisher"] == publisher]

    display(Markdown(f"# Video Game Sales Dashboard — {year_min} to {year_max}"))
    display_kpis(df_filtered)

    # Unified figure (equal subplot sizes)
    fig, axes = plt.subplots(
        2, 2, figsize=(10, 12), gridspec_kw={"width_ratios": [1, 1], "height_ratios": [1, 1]}
    )
    fig.suptitle(
        f"Interactive Dashboard for {region} ({year_min}–{year_max})",
        fontsize=16,
        fontweight="bold",
        y=0.98
    )

    # Adjust spacing
    plt.subplots_adjust(
        hspace=0.3,
        wspace=0.5,
        top=0.95,
        bottom=0.08,
        left=0.08,
        right=0.95
    )

    # ---------------- Subplot 1: Top 10 Games ----------------
    ax1 = axes[0, 0]
    top_games = (
        df_filtered.groupby("Name")[region]
        .sum()
        .sort_values(ascending=False)
        .head(10)
        .reset_index()
    )
    sns.barplot(
        data=top_games,
        x=region,
        y="Name",
        hue="Name",
        palette="viridis",
        legend=False,
        ax=ax1
    )
    ax1.set_title("Top 10 Games by Sales", fontsize=12)
    ax1.set_xlabel("Sales (Millions)")
    ax1.set_ylabel("")
    ax1.grid(axis="x", alpha=0.3)

    # ---------------- Subplot 2: Genre Distribution ----------------
    ax2 = axes[0, 1]
    genre_sales = (
        df_filtered.groupby("Genre")[region]
        .sum()
        .sort_values(ascending=False)
        .reset_index()
    )
    sns.barplot(
        data=genre_sales,
        x="Genre",
        y=region,
        hue="Genre",
        palette="pastel",
        legend=False,
        ax=ax2
    )
    ax2.set_title("Sales by Genre", fontsize=12)
    ax2.set_ylabel("Sales (Millions)")
    ax2.tick_params(axis="x", rotation=90)
    for tick in ax2.get_xticklabels():
      tick.set_fontsize(10)

    # ---------------- Subplot 3: Regional Breakdown ----------------
    ax3 = axes[1, 0]
    region_cols = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]
    regional_total = df_filtered[region_cols].sum()
    ax3.pie(
        regional_total,
        labels=regional_total.index,
        autopct="%1.1f%%",
        startangle=140,
        colors=sns.color_palette("Set2"),
        textprops={"fontsize": 9},
    )
    ax3.set_title("Regional Sales Share", fontsize=12)

    # ---------------- Subplot 4: Global Sales Trend ----------------
    ax4 = axes[1, 1]
    yearly_sales = (
        df_filtered.groupby("Year")["Global_Sales"].sum().reset_index().sort_values("Year")
    )
    sns.lineplot(
        data=yearly_sales,
        x="Year",
        y="Global_Sales",
        marker="o",
        color="coral",
        ax=ax4,
    )
    ax4.set_title("Global Sales Trend Over Time", fontsize=12)
    ax4.set_xlabel("Year")
    ax4.set_ylabel("Global Sales (Millions)")
    ax4.grid(True, linestyle="--", alpha=0.5)

    # Ensure all subplots have equal box size
    for ax_row in axes:
        for ax in ax_row:
            ax.set_box_aspect(1)

    # ---------------- Add center lines ----------------
    # Coordinates are in figure fraction (0 to 1)
    fig_width = 0.5  # middle of the figure (x)
    fig_height = 0.475  # middle of the figure (y)

    # Horizontal line
    fig.add_artist(plt.Line2D(
        [0.05, 0.95], [fig_height, fig_height],
        color="black", linestyle="--", linewidth=0.5, alpha=0.5, transform=fig.transFigure
    ))

    # Vertical line
    fig.add_artist(plt.Line2D(
        [fig_width, fig_width], [0.05, 0.95],
        color="black", linestyle="--", linewidth=0.5, alpha=0.5, transform=fig.transFigure
    ))

    plt.show()

# ==============================================================
# DASHBOARD LAYOUT
# ==============================================================
ui = VBox([
    year_range_slider,
    HBox([platform_dd, genre_dd, publisher_dd, region_dd])
])

out = interactive_output(
    update_dashboard,
    {
        "years": year_range_slider,
        "platform": platform_dd,
        "genre": genre_dd,
        "publisher": publisher_dd,
        "region": region_dd,
    },
)

display(ui, out)
# Out:
# VBox(children=(IntRangeSlider(value=(1980, 2016), continuous_update=False, description='Years:', layout=Layout…
# Output()
